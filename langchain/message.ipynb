# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI


load_dotenv()


model = ChatOpenAI(
    model="qwen3-32b",
    temperature=0,
    base_url=os.environ.get("COMPATIBLE_BASE_URL"),
    api_key=os.environ.get("COMPATIBLE_API_KEY"),  # pyright: ignore[reportArgumentType]
    extra_body={"enable_thinking": False},
)

# %%
from langchain.messages import SystemMessage, HumanMessage
from rich import print as rprint


system_msg = SystemMessage("你是一个精通 SQL 的专家。总是用一句话回答用户问题。")

messages = [system_msg, HumanMessage("什么是分组查询？")]

response = model.invoke(messages)
rprint(response)
# Out:
# AIMessage(
#     content='分组查询是使用 `GROUP BY`
# 子句将数据按一个或多个列进行分类，并对每个分组进行聚合计算（如求和、计数、平均等）的 SQL 查询方式。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 45,
#             'prompt_tokens': 36,
#             'total_tokens': 81,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': None
#         },
#         'model_provider': 'openai',
#         'model_name': 'qwen3-32b',
#         'system_fingerprint': None,
#         'id': 'chatcmpl-2312b261-2441-4631-9cc5-b6c54f3f82af',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--cc6c0b2f-ca66-407d-88af-1c3c98bc852e-0',
#     usage_metadata={
#         'input_tokens': 36,
#         'output_tokens': 45,
#         'total_tokens': 81,
#         'input_token_details': {},
#         'output_token_details': {}
#     }
# )

# %%
from langchain.agents import create_agent
from langchain.tools import tool


@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"


agent = create_agent(
    model=model,
    system_prompt="总是用中文回答用户问题。",  # System Message
    tools=[get_weather],
)
response = agent.invoke({"messages": [HumanMessage("What's the weather in Paris?")]})

rprint(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content="What's the weather in Paris?",
#             additional_kwargs={},
#             response_metadata={},
#             id='a2ca4b5c-81f1-4022-8f3f-a1bee4ef1ec6'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 19,
#                     'prompt_tokens': 164,
#                     'total_tokens': 183,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': None
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'qwen3-32b',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-19c7396b-448c-496f-ab19-dc8f66325f44',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
# ...

# %%
full_message
# Out:
# AIMessageChunk(content='Hello! How can I help you today? 😊', additional_kwargs={}, response_metadata={'model_provider': 'openai', 'finish_reason': 'stop', 'model_name': 'qwen3-max'}, id='lc_run--2a6e3789-1db9-417e-aa4a-d9987c6d9485', chunk_position='last')
